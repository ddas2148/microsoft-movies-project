# %%
import pandas as pd
import numpy as np

# %%
movie_gross =pd.read_csv('zippedData/bom.movie_gross.csv.gz')
movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
budget = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
budget.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
title_basics = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
title_ratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
#### now i am merging title to ratings to get movie name and ratings and vote together

title_ba_ra = pd.merge(title_basics,title_ratings)
title_ba_ra.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'averagerating', 'numvotes'],
#       dtype='object')

# %%
title_ba_ra.head(20)
# Out:
#        tconst                       primary_title  \
# 0   tt0063540                           Sunghursh
# 1   tt0066787     One Day Before the Rainy Season
# 2   tt0069049          The Other Side of the Wind
# 3   tt0069204                     Sabse Bada Sukh
# 4   tt0100275            The Wandering Soap Opera
# 5   tt0112502                             Bigfoot
# 6   tt0137204                     Joe Finds Grace
# 7   tt0146592                         Pál Adrienn
# 8   tt0154039                So Much for Justice!
# 9   tt0159369  Cooper and Hemingway: The True Gen
# 10  tt0162942        Children of the Green Dragon
# 11  tt0170651                T.G.M. - osvoboditel
# 12  tt0176694                  The Tragedy of Man
# 13  tt0192528                       Heaven & Hell
# 14  tt0230212                   The Final Journey
# 15  tt0247643    Los pájaros se van con la muerte
# 16  tt0249516                          Foodfight!
# 17  tt0250404                           Godfather
# ...

# %%
#### i will now taking off primary title, start year. to minimize the data set before i do another merge with other data set.
budget.drop('release_date', axis=1, inplace= True)

# %%
new_title_rating = title_ba_ra.drop(['primary_title','start_year'], axis=1, inplace= True)
new_title_rating.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-5712c4e5e266> in <module>
# ----> 1 new_title_rating = title_ba_ra.drop(['primary_title','start_year'], axis=1, inplace= True)
#       2 new_title_rating.info()
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
# ...

# %%
title_ba_ra.head(10)
# Out:
#       tconst                      original_title  start_year  runtime_minutes  \
# 0  tt0063540                           Sunghursh        2013            175.0
# 1  tt0066787                     Ashad Ka Ek Din        2019            114.0
# 2  tt0069049          The Other Side of the Wind        2018            122.0
# 3  tt0069204                     Sabse Bada Sukh        2018              NaN
# 4  tt0100275               La Telenovela Errante        2017             80.0
# 5  tt0112502                             Bigfoot        2017              NaN
# 6  tt0137204                     Joe Finds Grace        2017             83.0
# 7  tt0146592                         Pál Adrienn        2010            136.0
# 8  tt0154039                      Oda az igazság        2010            100.0
# 9  tt0159369  Cooper and Hemingway: The True Gen        2013            180.0
#
#                        genres  averagerating  numvotes
# 0          Action,Crime,Drama            7.0        77
# ...

# %% [markdown]
# ## heading

# %%
### i want see any movie have at least more than 6 average ratings
df.loc[df['year'] > 2010]

# %%
title_ba_ra.loc[title_ba_ra['averagerating'] > 6]
title_ba_ra.head()
title_ba_ra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73856 entries, 0 to 73855
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           73856 non-null  object
#  1   original_title   73856 non-null  object
#  2   start_year       73856 non-null  int64
#  3   runtime_minutes  66236 non-null  float64
#  4   genres           73052 non-null  object
#  5   averagerating    73856 non-null  float64
#  6   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
### also want to see those movies at least got >10 votes.

# %%
title_ba_ra = title_ba_ra.loc[title_ba_ra['numvotes'] >10]
title_ba_ra.head(20)
# Out:
#        tconst                      original_title  start_year  \
# 0   tt0063540                           Sunghursh        2013
# 1   tt0066787                     Ashad Ka Ek Din        2019
# 2   tt0069049          The Other Side of the Wind        2018
# 3   tt0069204                     Sabse Bada Sukh        2018
# 4   tt0100275               La Telenovela Errante        2017
# 5   tt0112502                             Bigfoot        2017
# 6   tt0137204                     Joe Finds Grace        2017
# 7   tt0146592                         Pál Adrienn        2010
# 8   tt0154039                      Oda az igazság        2010
# 9   tt0159369  Cooper and Hemingway: The True Gen        2013
# 10  tt0162942            A zöld sárkány gyermekei        2010
# 12  tt0176694                 Az ember tragédiája        2011
# 13  tt0192528                      Reverse Heaven        2018
# 15  tt0247643    Los pájaros se van con la muerte        2011
# ...

# %%
title_ba_ra.genres.()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-207d9e8c4721> in <module>
# ----> 1 title_ba_ra.genres.info()
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
title_ba_ra.loc[title_ba_ra['averagerating'] > 6.0]
title_ba_ra.head(20)
# Out:
#        tconst                      original_title  start_year  \
# 0   tt0063540                           Sunghursh        2013
# 1   tt0066787                     Ashad Ka Ek Din        2019
# 2   tt0069049          The Other Side of the Wind        2018
# 3   tt0069204                     Sabse Bada Sukh        2018
# 4   tt0100275               La Telenovela Errante        2017
# 5   tt0112502                             Bigfoot        2017
# 6   tt0137204                     Joe Finds Grace        2017
# 7   tt0146592                         Pál Adrienn        2010
# 8   tt0154039                      Oda az igazság        2010
# 9   tt0159369  Cooper and Hemingway: The True Gen        2013
# 10  tt0162942            A zöld sárkány gyermekei        2010
# 11  tt0170651                T.G.M. - osvoboditel        2018
# 12  tt0176694                 Az ember tragédiája        2011
# 13  tt0192528                      Reverse Heaven        2018
# ...

# %%
# Import pyplot for plotting
import matplotlib.pyplot as plt

# %matplotlib inline
