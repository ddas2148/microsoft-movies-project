# %%
import pandas as pd
import numpy as np
import re

# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
movie_gross =pd.read_csv('zippedData/bom.movie_gross.csv.gz')
movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
budget = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
budget.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budget = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
title_basics = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
title_basics.dropna(inplace=True)
title_basics['new_genres'] = title_basics['genres'].str.split(', ')
title_basics['new_genres'] = title_basics['new_genres'].apply(lambda x: list(set(x)))

# %%
title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                      A Thin Life                 A Thin Life
#
#    start_year  runtime_minutes                genres              new_genres
# 0        2013            175.0    Action,Crime,Drama    [Action,Crime,Drama]
# 1        2019            114.0       Biography,Drama       [Biography,Drama]
# 2        2018            122.0                 Drama                 [Drama]
# 4        2017             80.0  Comedy,Drama,Fantasy  [Comedy,Drama,Fantasy]
# 5        2018             75.0                Comedy                [Comedy]

# %%
df=title_basics.explode("new_genres")

# %%
df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                      A Thin Life                 A Thin Life
#
#    start_year  runtime_minutes                genres            new_genres
# 0        2013            175.0    Action,Crime,Drama    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama       Biography,Drama
# 2        2018            122.0                 Drama                 Drama
# 4        2017             80.0  Comedy,Drama,Fantasy  Comedy,Drama,Fantasy
# 5        2018             75.0                Comedy                Comedy

# %%
title_ratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
#### now i am merging title to ratings to get movie name and ratings and vote together

title_ba_ra = pd.merge(title_basics,title_ratings)
title_ba_ra.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'averagerating', 'numvotes'],
#       dtype='object')

# %%
title_ba_ra.head(20)
# Out:
#        tconst                       primary_title  \
# 0   tt0063540                           Sunghursh
# 1   tt0066787     One Day Before the Rainy Season
# 2   tt0069049          The Other Side of the Wind
# 3   tt0069204                     Sabse Bada Sukh
# 4   tt0100275            The Wandering Soap Opera
# 5   tt0112502                             Bigfoot
# 6   tt0137204                     Joe Finds Grace
# 7   tt0146592                         Pál Adrienn
# 8   tt0154039                So Much for Justice!
# 9   tt0159369  Cooper and Hemingway: The True Gen
# 10  tt0162942        Children of the Green Dragon
# 11  tt0170651                T.G.M. - osvoboditel
# 12  tt0176694                  The Tragedy of Man
# 13  tt0192528                       Heaven & Hell
# 14  tt0230212                   The Final Journey
# 15  tt0247643    Los pájaros se van con la muerte
# 16  tt0249516                          Foodfight!
# 17  tt0250404                           Godfather
# ...

# %%
#### i will now taking off primary title, start year. to minimize the data set before i do another merge with other data set.
budget.drop('release_date', axis=1, inplace= True)

# %%
title_ba_ra.head(10)
# Out:
#       tconst                      original_title  start_year  runtime_minutes  \
# 0  tt0063540                           Sunghursh        2013            175.0
# 1  tt0066787                     Ashad Ka Ek Din        2019            114.0
# 2  tt0069049          The Other Side of the Wind        2018            122.0
# 3  tt0069204                     Sabse Bada Sukh        2018              NaN
# 4  tt0100275               La Telenovela Errante        2017             80.0
# 5  tt0112502                             Bigfoot        2017              NaN
# 6  tt0137204                     Joe Finds Grace        2017             83.0
# 7  tt0146592                         Pál Adrienn        2010            136.0
# 8  tt0154039                      Oda az igazság        2010            100.0
# 9  tt0159369  Cooper and Hemingway: The True Gen        2013            180.0
#
#                        genres  averagerating  numvotes
# 0          Action,Crime,Drama            7.0        77
# ...

# %% [markdown]
# ## heading

# %%
### i want see any movie have at least more than 6 average ratings
df.loc[df['year'] > 2010]

# %%
title_ba_ra.loc[title_ba_ra['averagerating'] > 6]
title_ba_ra.head()
title_ba_ra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73856 entries, 0 to 73855
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           73856 non-null  object
#  1   original_title   73856 non-null  object
#  2   start_year       73856 non-null  int64
#  3   runtime_minutes  66236 non-null  float64
#  4   genres           73052 non-null  object
#  5   averagerating    73856 non-null  float64
#  6   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
### also want to see those movies at least got >10 votes.

# %%
title_ba_ra = title_ba_ra.loc[title_ba_ra['numvotes'] >10] 
title_ba_ra.head(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'numvotes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-249-94a80e1361b2> in <module>
# ----> 1 title_ba_ra = title_ba_ra.loc[title_ba_ra['numvotes'] >10]
#       2 title_ba_ra.head(20)
#
# ...

# %%
title_ratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
# Import pyplot for plotting
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df.dropna(inplace=True)
df['new_genres'] = df['genres'].str.split(',')
df['new_genres'] = df['new_genres'].apply(lambda x: list(set(x)))
df['new_genres'] = df['new_genres'].apply(lambda x: [[item] for item in x])
df1=df.explode("new_genres")
df2=df1.explode("new_genres")
df2.head(20)
# Out:
#        tconst                       primary_title  \
# 0   tt0063540                           Sunghursh
# 0   tt0063540                           Sunghursh
# 0   tt0063540                           Sunghursh
# 1   tt0066787     One Day Before the Rainy Season
# 1   tt0066787     One Day Before the Rainy Season
# 2   tt0069049          The Other Side of the Wind
# 4   tt0100275            The Wandering Soap Opera
# 4   tt0100275            The Wandering Soap Opera
# 4   tt0100275            The Wandering Soap Opera
# 5   tt0111414                         A Thin Life
# 7   tt0137204                     Joe Finds Grace
# 7   tt0137204                     Joe Finds Grace
# 7   tt0137204                     Joe Finds Grace
# 9   tt0144449               Nema aviona za Zagreb
# 10  tt0146592                         Pál Adrienn
# 11  tt0154039                So Much for Justice!
# 12  tt0159369  Cooper and Hemingway: The True Gen
# 13  tt0162942        Children of the Green Dragon
# ...

# %%
df3=df2[(df2.start_year > 2010) & (df2.new_genres == 'Crime')]
df3.head()
# Out:
#        tconst                primary_title               original_title  \
# 0   tt0063540                    Sunghursh                    Sunghursh
# 38  tt0315642                        Wazir                        Wazir
# 58  tt0365907  A Walk Among the Tombstones  A Walk Among the Tombstones
# 61  tt0372538                          Spy                          Spy
# 63  tt0376479            American Pastoral            American Pastoral
#
#     start_year  runtime_minutes              genres new_genres
# 0         2013            175.0  Action,Crime,Drama      Crime
# 38        2016            103.0  Action,Crime,Drama      Crime
# 58        2014            114.0  Action,Crime,Drama      Crime
# 61        2011            110.0  Action,Crime,Drama      Crime
# 63        2016            108.0         Crime,Drama      Crime

# %%
df1.new_genres.replace('[','')
df1.head()
# Out:
#       tconst                    primary_title   original_title  start_year  \
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 1  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
# 1  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
#
#    runtime_minutes              genres   new_genres
# 0            175.0  Action,Crime,Drama      [Crime]
# 0            175.0  Action,Crime,Drama      [Drama]
# 0            175.0  Action,Crime,Drama     [Action]
# 1            114.0     Biography,Drama  [Biography]
# 1            114.0     Biography,Drama      [Drama]

# %%
####  title_ba_ra[(title_ba_ra.averagerating > 7.0) & (title_ba_ra.genres == 'Action')]

# %%
df2=df1[(df1.start_year > 2013) & (df1.new_genres == '[Action]')]
df2.head()
# Out:
# Empty DataFrame
# Columns: [tconst, primary_title, original_title, start_year, runtime_minutes, genres, new_genres]
# Index: []

# %%
####= df. replace('[]', '', regex=True)

# %%
df3= df1.replace('[', ''), regex=True)
# Out:
#   File "<ipython-input-237-98b7a29fe262>", line 1
#     df3= df1.replace('[', ''), regex=True)
#                                          ^
# SyntaxError: unmatched ')'

# %%
title_ba_ra = pd.merge(title_basics,title_ratings)
title_ba_ra.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'averagerating', 'numvotes'],
#       dtype='object')

# %%
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
title_ba_ra['genres'].str.split(expand=True)
# Out:
#   File "<ipython-input-246-435d793c14e4>", line 1
#     title_ba_ra.['genres'].str.split(expand=True)
#                 ^
# SyntaxError: invalid syntax

# %%
title_ba_ra[(title_ba_ra.averagerating > 7.0) & (title_ba_ra.genres == 'Action')]
# Out:
#            tconst                                      primary_title  \
# 602    tt10075374                                  The Little Prince
# 604    tt10075836                     The Avengers Assemble Premiere
# 787    tt10254472                                      Alma de Héroe
# 888    tt10404502  Grisaia: Phantom trigger the animation 02. Sou...
# 1746    tt1283930                                       One Long Day
# ...           ...                                                ...
# 72862   tt9221238                                        Polis Evo 2
# 72989   tt9297624             Kamen Rider Heisei Generations Forever
# 73638   tt9737984                                            Striker
# 73664   tt9760512                                    D/O Parvathamma
# 73761   tt9838780                               Hidden Dragon Battle
#
#                                           original_title  start_year  \
# ...

# %%
title_ba_ra[['g1','g2','g3']]= title_ba_ra['genres'].str.split(',',expand=True)
title_ba_ra.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'genres'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-1b9c21a73cbe> in <module>
# ----> 1 title_ba_ra[['g1','g2','g3']]= title_ba_ra['genres'].str.split(',',expand=True)
#       2 title_ba_ra.head(10)
#
# ...

# %%
movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
### changing column names for title.
movie_gross.rename({'title' :'primary_title'}, axis = 1, inplace =True)
movie_gross.head()
# Out:
#                                  primary_title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
title_ba_ra.describe()
# Out:
#        domestic_gross         year   start_year  runtime_minutes  \
# count    3.005000e+03  3027.000000  3027.000000      2980.000000
# mean     3.064033e+07  2014.077635  2013.783284       107.217114
# std      6.671629e+07     2.442245     2.466955        20.073886
# min      1.000000e+02  2010.000000  2010.000000         3.000000
# 25%      1.390000e+05  2012.000000  2012.000000        94.000000
# 50%      2.000000e+06  2014.000000  2014.000000       105.000000
# 75%      3.250000e+07  2016.000000  2016.000000       118.000000
# max      7.001000e+08  2018.000000  2019.000000       272.000000
#
#        averagerating      numvotes
# count    3027.000000  3.027000e+03
# mean        6.457582  6.170030e+04
# std         1.012277  1.255132e+05
# min         1.600000  5.000000e+00
# 25%         5.900000  2.117000e+03
# 50%         6.600000  1.310900e+04
# 75%         7.100000  6.276550e+04
# max         9.200000  1.841066e+06

# %%
title_ba_ra.head(2)
# Out:
#   primary_title studio  domestic_gross foreign_gross  year     tconst  \
# 0   Toy Story 3     BV     415000000.0     652000000  2010  tt0435761
# 1     Inception     WB     292600000.0     535700000  2010  tt1375666
#
#   original_title  start_year  runtime_minutes                      genres  \
# 0    Toy Story 3        2010            103.0  Adventure,Animation,Comedy
# 1      Inception        2010            148.0     Action,Adventure,Sci-Fi
#
#    averagerating  numvotes         g1         g2      g3
# 0            8.3    682218  Adventure  Animation  Comedy
# 1            8.8   1841066     Action  Adventure  Sci-Fi

# %%
title_ba_ra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3027 entries, 0 to 3026
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   primary_title    3027 non-null   object
#  1   studio           3024 non-null   object
#  2   domestic_gross   3005 non-null   float64
#  3   foreign_gross    1832 non-null   object
#  4   year             3027 non-null   int64
#  5   tconst           3027 non-null   object
#  6   original_title   3027 non-null   object
#  7   start_year       3027 non-null   int64
#  8   runtime_minutes  2980 non-null   float64
#  9   genres           3020 non-null   object
#  10  averagerating    3027 non-null   float64
#  11  numvotes         3027 non-null   int64
#  12  g1               3020 non-null   object
#  13  g2               2395 non-null   object
#  14  g3               1563 non-null   object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 378.4+ KB

# %%
budgets = pd.read_csv('zippedData/tn.movie_budgets.csv')
budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
title_ba_ra.head()
# Out:
# 0    652000000.0
# 1    535700000.0
# 2    513900000.0
# 3    398000000.0
# 4    311500000.0
# Name: foreign_gross, dtype: float64

# %%
title_ba_ra.drop('id', axis=1, inplace= True)

# %%
title_ba_ra.drop('primary_title', axis=1, inplace=True)

# %%
title_ba_ra.drop('production_budget', axis=1, inplace=True)

# %%
title_ba_ra.drop('domestic_gross', axis=1, inplace=True)

# %%
title_ba_ra.drop('worldwide_gross', axis=1, inplace=True)

# %%
title_ba_ra.head()
# Out:
# 0    652000000.0
# 1    535700000.0
# 2    513900000.0
# 3    398000000.0
# 4    311500000.0
# Name: foreign_gross, dtype: float64

# %%
title_ba_ra.dtypes
# Out:
# dtype('float64')

# %%
#### change data type
import reg

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bvalgard/How-to-str.split-/master/fav_foods.csv')

# %%
df.head()
# Out:
#    id                      email                           favorite_foods
# 0   1    liberty.hayes@email.com  apple pie, hot dog, macaroni and cheese
# 1   2   mallory.spears@email.com              sushi, fried chicken, pizza
# 2   3      easton.lara@email.com         enchiladas, apple pie, hamburger
# 3   4   jaslyn.mathews@email.com                steak, hamburger, hot dog
# 4   5  juliet.erickson@email.com                        poutine, sandwich

# %%
df.dropna(inplace=True)
df['list_of_lists'] = df['favorite_foods'].str.split(', ')
df['list_of_lists'] = df['list_of_lists'].apply(lambda x: list(set(x)))
df['list_of_lists'] = df['list_of_lists'].apply(lambda x: [list](set(x)))
# Out:
# <>:4: SyntaxWarning: 'list' object is not callable; perhaps you missed a comma?
# <>:4: SyntaxWarning: 'list' object is not callable; perhaps you missed a comma?
# <ipython-input-210-c3d0fbd7a56d>:4: SyntaxWarning: 'list' object is not callable; perhaps you missed a comma?
#   df['list_of_lists'] = df['list_of_lists'].apply(lambda x: [list](set(x)))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-210-c3d0fbd7a56d> in <module>
#       2 df['list_of_lists'] = df['favorite_foods'].str.split(', ')
#       3 df['list_of_lists'] = df['list_of_lists'].apply(lambda x: list(set(x)))
# ----> 4 df['list_of_lists'] = df['list_of_lists'].apply(lambda x: [list](set(x)))
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
# ...

# %%
df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                      A Thin Life                 A Thin Life
#
#    start_year  runtime_minutes                genres            new_genres
# 0        2013            175.0    Action,Crime,Drama    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama       Biography,Drama
# 2        2018            122.0                 Drama                 Drama
# 4        2017             80.0  Comedy,Drama,Fantasy  Comedy,Drama,Fantasy
# 5        2018             75.0                Comedy                Comedy

# %%
df.favorite_foods.str.split(expand=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-187-0db95d61beef> in <module>
# ----> 1 df.favorite_foods.str.split(expand=True)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'favorite_foods'

# %%
df = df.explode("genres")

# %%
df.str.split(expand=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-191-16954b242e3d> in <module>
# ----> 1 df.str.split(expand=True)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
df.explode(("list_of_lists")
# Out:
#   File "<ipython-input-157-422a9c5a31db>", line 1
#     df.explode(("list_of_lists")
#                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
#####   title_ba_ra[(title_ba_ra.averagerating > 7.0) & (title_ba_ra.genres == 'Action')]

# %%
df[(df.list_of_lists == '[hot dog]')]
df.head()
# Out:
#    id                      email                           favorite_foods  \
# 0   1    liberty.hayes@email.com  apple pie, hot dog, macaroni and cheese
# 1   2   mallory.spears@email.com              sushi, fried chicken, pizza
# 2   3      easton.lara@email.com         enchiladas, apple pie, hamburger
# 3   4   jaslyn.mathews@email.com                steak, hamburger, hot dog
# 4   5  juliet.erickson@email.com                        poutine, sandwich
#
#                                      list_of_lists
# 0  [[macaroni and cheese], [apple pie], [hot dog]]
# 1              [[sushi], [fried chicken], [pizza]]
# 2         [[enchiladas], [hamburger], [apple pie]]
# 3                [[steak], [hamburger], [hot dog]]
# 4                          [[sandwich], [poutine]]

# %%
df= df.explode("list_of_lists")

# %%
df.head()
# Out:
#    id                     email                           favorite_foods  \
# 0   1   liberty.hayes@email.com  apple pie, hot dog, macaroni and cheese
# 0   1   liberty.hayes@email.com  apple pie, hot dog, macaroni and cheese
# 0   1   liberty.hayes@email.com  apple pie, hot dog, macaroni and cheese
# 1   2  mallory.spears@email.com              sushi, fried chicken, pizza
# 1   2  mallory.spears@email.com              sushi, fried chicken, pizza
#
#            list_of_lists
# 0  [macaroni and cheese]
# 0            [apple pie]
# 0              [hot dog]
# 1                [sushi]
# 1        [fried chicken]

# %%
######## title_new = title_ba_ra.foreign_gross.str.replace(',','').astype(float)

# %%
df.dropna(inplace=True)
df['list_of_lists'] = df['favorite_foods'].str.split(', ')
df['list_of_lists'] = df['list_of_lists'].apply(lambda x: list(set(x)))
df['list_of_lists'] = df['list_of_lists'].apply(lambda x: list(set(x)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'favorite_foods'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-199-9fdf44dfe9f8> in <module>
# ...

# %%
df.head()
# Out:
# 0   NaN
# 0   NaN
# 0   NaN
# 1   NaN
# 1   NaN
# Name: list_of_lists, dtype: float64

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bvalgard/How-to-str.split-/master/fav_foods.csv') # you can use this link it will work (no need to download csv)
df.dropna(inplace=True)
df['list_of_lists'] = df['favorite_foods'].str.split(', ')
df['list_of_lists'] = df['list_of_lists'].apply(lambda x: list(set(x)))
df['list_of_lists'] = df['list_of_lists'].apply(lambda x: [[item] for item in x])
df1=df.explode("new_genres")
df2=df1.explode("new_genres")
df2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new_genres'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-242-93157010e418> in <module>
# ...

# %%
df.head()
# Out:
#    id                      email                           favorite_foods  \
# 0   1    liberty.hayes@email.com  apple pie, hot dog, macaroni and cheese
# 1   2   mallory.spears@email.com              sushi, fried chicken, pizza
# 2   3      easton.lara@email.com         enchiladas, apple pie, hamburger
# 3   4   jaslyn.mathews@email.com                steak, hamburger, hot dog
# 4   5  juliet.erickson@email.com                        poutine, sandwich
#
#                                      list_of_lists
# 0  [[macaroni and cheese], [apple pie], [hot dog]]
# 1              [[sushi], [fried chicken], [pizza]]
# 2         [[enchiladas], [hamburger], [apple pie]]
# 3                [[steak], [hamburger], [hot dog]]
# 4                          [[sandwich], [poutine]]
